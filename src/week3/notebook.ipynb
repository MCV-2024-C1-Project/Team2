# %%
import pickle

# Replace 'filename.pkl' with your actual file name
with open('../../datasets/qsd2_w3/gt_corresps.pkl', 'rb') as file:
    data = pickle.load(file)

# Now, `data` contains the object stored in the pickle file
print(data)
# Out:
# [[236], [107], [280, 285], [259], [86], [94, 132], [258, 35], [258, 35], [104, 130], [131], [282], [199, 34], [53, 124], [28], [260], [215], [163], [25], [30], [176, 128], [110], [7], [251], [183], [179], [270], [93], [200], [161], [182, 252]]

# %%
import utils
list_results_k_1=[[236], [107], [280, 285], [259], [86], [94, 132], [258, 35], [258, 35], [104, 130], [131], [282], [199, 34], [53, 124], [28], [260], [215], [163], [25], [30], [176, 128], [110], [7], [251], [183], [179], [270], [93], [200], [161], [182, 252]]
list_results_k_5=[[272, 90, 105, 121, 133], [276, 204, 259, 122, 248], [[3, 60, 85, 261, 114], [60, 178, 82, 119, 221]], [60, 178, 82, 119, 221], [103, 246, 244, 225, 218], [96, 118, 249, 268, 270], [[261, 83, 29, 11, 237], [16, 193, 135, 258, 119]], [16, 193, 135, 258, 119], [[81, 14, 227, 61, 47], [22, 280, 208, 95, 4]], [22, 280, 208, 95, 4], [[169, 120, 24, 149, 193], [209, 32, 236, 208, 95]], [209, 32, 236, 208, 95], [[279, 23, 74, 273, 234], [125, 54, 51, 272, 73]], [125, 54, 51, 272, 73], [171, 8, 135, 88, 21], [233, 79, 182, 245, 156], [[251, 9, 94, 154, 179], [157, 129, 39, 37, 148]], [157, 129, 39, 37, 148], [82, 187, 200, 43, 120], [257, 215, 174, 205, 76], [21, 187, 230, 122, 44], [126, 60, 179, 76, 102], [7, 260, 29, 167, 133], [94, 24, 189, 113, 49], [281, 190, 258, 285, 255], [[44, 13, 29, 244, 252], [41, 124, 234, 52, 85]], [41, 124, 234, 52, 85], [75, 157, 258, 94, 43], [[255, 273, 212, 237, 45], [261, 264, 177, 105, 282]], [261, 264, 177, 105, 282], [58, 103, 49, 34, 24], [88, 33, 123, 95, 26], [271, 120, 114, 259, 104], [125, 62, 173, 204, 101], [240, 99, 209, 249, 71], [42, 204, 192, 283, 73], [166, 235, 123, 13, 16], [[102, 42, 162, 279, 8], [258, 40, 234, 210, 29]], [258, 40, 234, 210, 29]]

mapk_k1 = utils.mapk(data, list_results_k_1, k=1)
mapk_k5 = utils.mapk(data, list_results_k_5, k=5)
print(mapk_k5)
# Out:
# 0.15416666666666667
